# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
BASE_PATH = os.path.join(os.getcwd(), "..", "..", "..")
MODULES_PATH = os.path.join(BASE_PATH, "modules")
METRICS_PATH = os.path.join(BASE_PATH, "metrics")

# %%
sys.path.append(MODULES_PATH)
sys.path.append(os.path.join(BASE_PATH, "tf_al"))

# %%
from tf_al import ExperimentSuitMetrics
from utils import MetricsTransformer, Frame, ExperimentFrame

# %%
dtypes = {
    "run": int,
    "iteration": int,
    "train_time": float,
    "eval_sparse_categorical_crossentropy": float,
    "eval_sparse_categorical_accuracy": float,
    "query_time": float,
    "labeled_pool_size": int,
    "unlabeled_pool_size": int,
    "method": str
}

# %%
#train_loss train_sparse_categorical_accuracy train_time query_time eval_sparse_categorical_crossentropy eval_sparse_categorical_accuracy eval_time indices_selected iteration labeled_pool_size unlabeled_pool_size

# %%
base_experiment_path = os.path.join(METRICS_PATH, "temp_1")
metrics_handler = ExperimentSuitMetrics(base_experiment_path)
df_mp = MetricsTransformer.load_from_dir(metrics_handler, "moment_propagation", dtype=dtypes)

# %%
selector = df_mp["eval_sparse_categorical_accuracy"] > .7
sns.lineplot(data=df_mp[selector], x="labeled_pool_size", y="eval_sparse_categorical_accuracy", hue="method")
# Out:
# <AxesSubplot:xlabel='labeled_pool_size', ylabel='eval_sparse_categorical_accuracy'>

# %%
# %autoreload 2
from tf_al.score import leff, qeff
mp_methods = Frame.split_by(df_mp, "method")
mp_methods = Frame.mean(mp_methods, "iteration", ["method"])

# %%
mp_mean = pd.concat(mp_methods)

# %%
sns.lineplot(data=mp_mean, x="labeled_pool_size", y="eval_sparse_categorical_accuracy", hue="method")
# Out:
# <AxesSubplot:xlabel='labeled_pool_size', ylabel='eval_sparse_categorical_accuracy'>

# %%
# %autoreload 2
from utils import ExperimentFrame, FrameScores
df_mp = MetricsTransformer.load_from_dir(metrics_handler, "moment_propagation", dtype=dtypes)
scores = FrameScores(accuracy_column="eval_sparse_categorical_accuracy")
frame = ExperimentFrame(df_mp, scores=scores)

# %%
ent_frame = frame.get_frame(method="Max. Entropy")
ent_frame
# Out:
#     mean_leff  run               model        method  \
# 0    1.000000    0  Moment Propagation  Max. Entropy
# 1    0.880000    0  Moment Propagation  Max. Entropy
# 2    0.851852    0  Moment Propagation  Max. Entropy
# 3    1.013333    0  Moment Propagation  Max. Entropy
# 4    0.986667    0  Moment Propagation  Max. Entropy
# ..        ...  ...                 ...           ...
# 95   1.063830    1  Moment Propagation  Max. Entropy
# 96   1.042105    1  Moment Propagation  Max. Entropy
# 97   1.031250    1  Moment Propagation  Max. Entropy
# 98   1.053191    1  Moment Propagation  Max. Entropy
# 99   1.042105    1  Moment Propagation  Max. Entropy
#
#                                            train_loss  \
# 0   [2.4242777824401855, 2.435490846633911, 1.7544...
# 1   [2.5867624282836914, 2.1679489612579346, 1.462...
# 2   [2.4481043815612793, 1.9407039880752563, 1.748...
# 3   [2.4106457233428955, 1.9433822631835938, 1.678...
# 4   [2.4811441898345947, 2.119846820831299, 1.8536...
# ..                                                ...
# 95  [2.206115961074829, 1.6679505109786987, 1.3101...
# 96  [2.1816930770874023, 1.702030897140503, 1.3029...
# 97  [2.2050621509552, 1.7245128154754639, 1.408756...
# 98  [2.2184717655181885, 1.724592685699463, 1.3971...
# 99  [2.2510998249053955, 1.793147087097168, 1.4070...
#
#                     train_sparse_categorical_accuracy  train_time  query_time  \
# 0   [0.9805825352668762, 0.10000000149011612, 0.40...    1.397389   13.650333
# 1   [0.47999998927116394, 0.2666666805744171, 0.56...    1.540524    6.676497
# 2   [0.5285714268684387, 0.3499999940395355, 0.449...    1.741291    6.473444
# 3   [0.5444444417953491, 0.3400000035762787, 0.460...    1.881624    6.726900
# 4   [0.5363636612892151, 0.25, 0.4166666567325592,...    2.026704    6.616202
# ..                                                ...         ...         ...
# 95  [0.5839378237724304, 0.41237112879753113, 0.53...   21.772091    7.114212
# 96  [0.5856410264968872, 0.3979591727256775, 0.551...   21.766454    6.735028
# 97  [0.5928934216499329, 0.40505051612854004, 0.52...   20.925060    6.799164
# 98  [0.5773869156837463, 0.38999998569488525, 0.48...   20.635936    7.017764
# 99  [0.5761194229125977, 0.35544553399086, 0.49702...   21.893315    6.807909
#
#     eval_sparse_categorical_crossentropy  eval_sparse_categorical_accuracy  \
# 0                               0.965184                              0.71
# 1                               0.920014                              0.66
# 2                               1.003960                              0.69
# 3                               0.940759                              0.76
# 4                               0.820614                              0.74
# ..                                   ...                               ...
# 95                              0.104707                              1.00
# 96                              0.096904                              0.99
# 97                              0.086931                              0.99
# 98                              0.107099                              0.99
# 99                              0.094310                              0.99
#
#                eval_time                                   indices_selected  \
# 0   0.029534101486206055  [40542, 49339, 41787, 16877, 24658, 48124, 499...
# 1    0.04404592514038086  [52029, 45973, 7483, 45490, 58935, 19340, 1938...
# 2    0.02340841293334961  [54542, 53399, 10082, 33233, 2321, 55050, 3538...
# 3   0.047908782958984375  [1268, 48484, 41747, 48374, 771, 4990, 28280, ...
# 4   0.029155254364013672  [31804, 27197, 6839, 23880, 2822, 40792, 17112...
# ..                   ...                                                ...
# 95  0.027248859405517578  [38077, 26999, 8721, 1790, 31573, 14313, 41385...
# 96  0.030599594116210938  [20232, 31692, 14879, 26758, 58273, 33536, 254...
# 97  0.029009342193603516  [33530, 55378, 5354, 19009, 9635, 36967, 29064...
# 98   0.04242062568664551  [27275, 27753, 45678, 7242, 39302, 49870, 3403...
# 99  0.031914472579956055  [19687, 1318, 54013, 36672, 29599, 19940, 5010...
#
#     iteration  labeled_pool_size  unlabeled_pool_size
# 0           1                 20                59870
# 1           2                 30                59860
# 2           3                 40                59850
# 3           4                 50                59840
# 4           5                 60                59830
# ..        ...                ...                  ...
# 95         96                970                58920
# 96         97                980                58910
# 97         98                990                58900
# 98         99               1000                58890
# 99        100               1010                58880
#
# [200 rows x 15 columns]

# %%
mean_frame = ent_frame.groupby("iteration", as_index=False).mean()
mean_frame
# Out:
#     iteration  mean_leff  run  train_time  query_time  \
# 0           1   1.000000  0.5    1.430514   10.488866
# 1           2   0.957857  0.5    1.596024    6.862950
# 2           3   0.961014  0.5    1.836141    6.804907
# 3           4   1.050145  0.5    2.011254    6.927296
# 4           5   0.938539  0.5    2.171797    6.879435
# ..        ...        ...  ...         ...         ...
# 95         96   1.047704  0.5   20.573663    6.835495
# 96         97   1.031579  0.5   20.586035    6.689698
# 97         98   1.015625  0.5   20.509800    6.784251
# 98         99   1.042385  0.5   20.347738    6.673023
# 99        100   1.036678  0.5   20.634800    6.778998
#
#     eval_sparse_categorical_crossentropy  eval_sparse_categorical_accuracy  \
# 0                               1.328153                             0.580
# 1                               1.227078                             0.620
# 2                               1.150893                             0.650
# 3                               0.929187                             0.755
# 4                               0.898563                             0.695
# ..                                   ...                               ...
# 95                              0.111626                             0.990
# 96                              0.106853                             0.980
# 97                              0.109435                             0.975
# 98                              0.120652                             0.985
# 99                              0.092435                             0.990
#
#     labeled_pool_size  unlabeled_pool_size
# 0                20.0              59870.0
# 1                30.0              59860.0
# 2                40.0              59850.0
# 3                50.0              59840.0
# 4                60.0              59830.0
# ..                ...                  ...
# 95              970.0              58920.0
# 96              980.0              58910.0
# 97              990.0              58900.0
# 98             1000.0              58890.0
# 99             1010.0              58880.0
#
# [100 rows x 9 columns]

# %%
mean_frame_len = mean_frame.shape[0]
mean_frame_len
# Out:
# 100

# %%
columns = Frame.get_columns(ent_frame, ["model", "method"])[:mean_frame_len]
columns
# Out:
#                  model        method
# 0   Moment Propagation  Max. Entropy
# 1   Moment Propagation  Max. Entropy
# 2   Moment Propagation  Max. Entropy
# 3   Moment Propagation  Max. Entropy
# 4   Moment Propagation  Max. Entropy
# ..                 ...           ...
# 95  Moment Propagation  Max. Entropy
# 96  Moment Propagation  Max. Entropy
# 97  Moment Propagation  Max. Entropy
# 98  Moment Propagation  Max. Entropy
# 99  Moment Propagation  Max. Entropy
#
# [100 rows x 2 columns]

# %%
Frame.update(mean_frame, columns)

# %%
mean_frame
# Out:
#                         model        method  mean_leff  run  train_time  \
# iteration
# 1          Moment Propagation  Max. Entropy   1.000000  0.5    1.430514
# 2          Moment Propagation  Max. Entropy   0.957857  0.5    1.596024
# 3          Moment Propagation  Max. Entropy   0.961014  0.5    1.836141
# 4          Moment Propagation  Max. Entropy   1.050145  0.5    2.011254
# 5          Moment Propagation  Max. Entropy   0.938539  0.5    2.171797
# ...                       ...           ...        ...  ...         ...
# 96         Moment Propagation  Max. Entropy   1.047704  0.5   20.573663
# 97         Moment Propagation  Max. Entropy   1.031579  0.5   20.586035
# 98         Moment Propagation  Max. Entropy   1.015625  0.5   20.509800
# 99         Moment Propagation  Max. Entropy   1.042385  0.5   20.347738
# 100                       NaN           NaN   1.036678  0.5   20.634800
#
#            query_time  eval_sparse_categorical_crossentropy  \
# iteration
# 1           10.488866                              1.328153
# 2            6.862950                              1.227078
# 3            6.804907                              1.150893
# 4            6.927296                              0.929187
# 5            6.879435                              0.898563
# ...               ...                                   ...
# 96           6.835495                              0.111626
# 97           6.689698                              0.106853
# 98           6.784251                              0.109435
# 99           6.673023                              0.120652
# 100          6.778998                              0.092435
#
#            eval_sparse_categorical_accuracy  labeled_pool_size  \
# iteration
# 1                                     0.580               20.0
# 2                                     0.620               30.0
# 3                                     0.650               40.0
# 4                                     0.755               50.0
# 5                                     0.695               60.0
# ...                                     ...                ...
# 96                                    0.990              970.0
# 97                                    0.980              980.0
# 98                                    0.975              990.0
# 99                                    0.985             1000.0
# 100                                   0.990             1010.0
#
#            unlabeled_pool_size
# iteration
# 1                      59870.0
# 2                      59860.0
# 3                      59850.0
# 4                      59840.0
# 5                      59830.0
# ...                        ...
# 96                     58920.0
# 97                     58910.0
# 98                     58900.0
# 99                     58890.0
# 100                    58880.0
#
# [100 rows x 10 columns]

# %%
frame.get_frame(method="Max. Entropy").groupby("iteration").mean()
# Out:
#            mean_leff  run  train_time  query_time  \
# iteration
# 1           1.000000  0.5    1.430514   10.488866
# 2           0.957857  0.5    1.596024    6.862950
# 3           0.961014  0.5    1.836141    6.804907
# 4           1.050145  0.5    2.011254    6.927296
# 5           0.938539  0.5    2.171797    6.879435
# ...              ...  ...         ...         ...
# 96          1.047704  0.5   20.573663    6.835495
# 97          1.031579  0.5   20.586035    6.689698
# 98          1.015625  0.5   20.509800    6.784251
# 99          1.042385  0.5   20.347738    6.673023
# 100         1.036678  0.5   20.634800    6.778998
#
#            eval_sparse_categorical_crossentropy  \
# iteration
# 1                                      1.328153
# 2                                      1.227078
# 3                                      1.150893
# 4                                      0.929187
# 5                                      0.898563
# ...                                         ...
# 96                                     0.111626
# 97                                     0.106853
# 98                                     0.109435
# 99                                     0.120652
# 100                                    0.092435
#
#            eval_sparse_categorical_accuracy  labeled_pool_size  \
# iteration
# 1                                     0.580               20.0
# 2                                     0.620               30.0
# 3                                     0.650               40.0
# 4                                     0.755               50.0
# 5                                     0.695               60.0
# ...                                     ...                ...
# 96                                    0.990              970.0
# 97                                    0.980              980.0
# 98                                    0.975              990.0
# 99                                    0.985             1000.0
# 100                                   0.990             1010.0
#
#            unlabeled_pool_size
# iteration
# 1                      59870.0
# 2                      59860.0
# 3                      59850.0
# 4                      59840.0
# 5                      59830.0
# ...                        ...
# 96                     58920.0
# 97                     58910.0
# 98                     58900.0
# 99                     58890.0
# 100                    58880.0
#
# [100 rows x 8 columns]

# %%
frame.get_mean_frame(method="Random")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_25557/2993830110.py in <module>
# ----> 1 frame.get_mean_frame(method="Random")
#
# ~/Desktop/workspace/thesis/wp/notebooks/experiments/mnist/../../../modules/utils/experiment_frame.py in get_mean_frame(self, method, model, ids)
#     113     def get_mean_frame(self, method=None, model=None, ids=["model", "method"]):
#     114         frame = self.get_frame(method, model)
# --> 115         return Frame.mean(frame, "iteration", ids)
#     116
#     117
#
# ~/Desktop/workspace/thesis/wp/notebooks/experiments/mnist/../../../modules/utils/frame.py in mean(frames, groupby_key, ids)
#     100         for frame in frames:
#     101
# --> 102             mean_frame = frame.groupby(groupby_key).mean()
#     103             if ids is not None:
#     104                 mean_len = mean_frame.shape[0]
#
# AttributeError: 'str' object has no attribute 'groupby'

# %%
Frame.mean(, "run")

# %%
sns.lineplot(data=, x="labeled_pool_size", y="eval_sparse_categorical_accuracy", hue="method")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_25557/2842709512.py in <module>
# ----> 1 sns.lineplot(data=Frame.mean(frame.get_frame(method="Random"), "run"), x="labeled_pool_size", y="eval_sparse_categorical_accuracy", hue="method")
#
# ~/Desktop/workspace/thesis/wp/notebooks/experiments/mnist/../../../modules/utils/frame.py in mean(frames, groupby_key, ids)
#     100         for frame in frames:
#     101
# --> 102             mean_frame = frame.groupby(groupby_key).mean()
#     103             if ids is not None:
#     104                 mean_len = mean_frame.shape[0]
#
# AttributeError: 'str' object has no attribute 'groupby'

# %%
sns.lineplot(data=frame.get_frame(), x="labeled_pool_size", y="mean_leff", hue="method")
# Out:
# <AxesSubplot:xlabel='labeled_pool_size', ylabel='mean_leff'>

# %%
mean_ar = np.array([9.04820891, 9.04820891])
(mean_ar-np.min(mean_ar))/(np.max(mean_ar)-np.min(mean_ar))
# Out:
# /tmp/ipykernel_25557/1840450400.py:2: RuntimeWarning: invalid value encountered in true_divide
#   (mean_ar-np.min(mean_ar))/(np.max(mean_ar)-np.min(mean_ar))
# array([nan, nan])

# %%
np.max(mean_ar)-np.min(mean_ar)
# Out:
# 0.0

# %%
ExperimentFrame()

# %%
bald_res = mp_methods[0]
rand_res = mp_methods[-1]
ratio_res = mp_methods[2]
entr_res = mp_methods[1]
std_res = mp_methods[3]

# %%
key = "eval_sparse_categorical_accuracy"
rand_acc = rand_res[key].to_numpy()
bald_acc = bald_res[key].to_numpy()
ratio_acc = ratio_res[key].to_numpy()
pool_size = bald_res["labeled_pool_size"]

bald_mean_leff, bald_std_leff = leff(bald_acc, rand_acc)
ratio_mean_leff, ratio_std_leff = leff(ratio_acc, rand_acc)
rand_mean_leff, rand_std_leff = leff(rand_acc, rand_acc)

# %%
accum = [bald_mean_leff[0]]
for val in bald_mean_leff[1:]:
    accum.append(accum[-1]+val)

# %%
df_bald_leff = pd.DataFrame({"leff": bald_mean_leff, "acc": bald_acc, "method": ["bald"]*len(bald_acc), "size": pool_size})
df_ratio_leff = pd.DataFrame({"leff": ratio_mean_leff, "acc": ratio_acc, "method": ["ratio"]*len(bald_acc), "size": pool_size})
df_random_leff = pd.DataFrame({"leff": rand_mean_leff, "acc": rand_acc, "method": ["random"]*len(rand_acc), "size": pool_size})

df_leff_test = pd.concat([df_bald_leff, df_ratio_leff, df_random_leff])

# %%
from tf_al.score import runtime

# %%
bald_qt = bald_res["query_time"].to_numpy()
rand_qt = rand_res["query_time"].to_numpy()
ratio_qt = ratio_res["query_time"].to_numpy()
std_qt = std_res["query_time"].to_numpy()
ent_qt = entr_res["query_time"].to_numpy()

# %%
pool_sizes = bald_res["unlabeled_pool_size"]
run_mean, run_std, runtime(bald_qt, pool_sizes)
# Out:
# (0.00015268572810579113, 9.820578162181209e-06)

# %%
bald_mean = np.mean(bald_qt/pool_sizes)
rand_mean = np.mean(rand_qt/pool_sizes)
ratio_mean = np.mean(ratio_qt/pool_sizes)
ent_mean = np.mean(ent_qt/pool_sizes)
std_mean = np.mean(std_qt/pool_sizes)

# %%
print("Times")
print("Ratios: ", ratio_mean)
print("Bald: ", bald_mean)
print("Std: ", std_mean)
print("Entropy: ", ent_mean)
print("Random: ", rand_mean)
# Out:
# Times
# Ratios:  0.00011220628071031985
# Bald:  0.00015268572810579113
# Std:  0.00011382029332352505
# Entropy:  0.00011472658660925107
# Random:  7.557685550409977e-07

# %%
values = [ratio_mean, bald_mean, std_mean, ent_mean]
labels = ["ratio", "bald", "std", "entropy"]

# %%
res = (np.array(values)-np.min(values))/(np.max(values)-np.min(values))
res = np.abs(res -1)

# %%
df = pd.DataFrame({"time": res, "method": labels})

# %%
ax = sns.barplot(data=df, x="method", y="time")
ax.set(ylabel="Query efficency", xlabel="Method")
# Out:
# [Text(0, 0.5, 'Query efficency'), Text(0.5, 0, 'Method')]

# %%
bald_qeff = (bald_mean-rand_mean)/bald_mean
ratio_qeff = (ratio_mean-rand_mean)/ratio_mean
ent_qeff = (ent_mean-rand_mean)/ent_mean
std_qeff = (std_mean-rand_mean)/std_mean

# %%
ratio_mean
# Out:
# 0.00011220628071031985

# %%
bald_mean/ratio_mean
# Out:
# 1.3607591940416959

# %%
()
# Out:
# ()

# %%
sum_qeff = ((ratio_qeff+ent_qeff+std_qeff)/3)
(bald_qeff-sum_qeff)/max(sum_qeff, bald_qeff)
# Out:
# 0.0017130169207048868

# %%
(bald_qeff/ratio_qeff)/2
# Out:
# 0.5008989031139479

# %%
(ratio_qeff/bald_qeff)/2
# Out:
# 0.4991027100395312

# %%
bald_qeff
# Out:
# 0.9950501689685276

# %%
sns.lineplot(data=df_leff_test, x="size", y="leff", hue="method")
# Out:
# <AxesSubplot:xlabel='size', ylabel='leff'>

# %%
df_mc = MetricsTransformer.load_from_dir(metrics_handler, "mc_dropout", dtype=dtypes)
selector = df_mc["eval_sparse_categorical_accuracy"] > .7
sns.lineplot(data=df_mc[selector], x="labeled_pool_size", y="eval_sparse_categorical_accuracy", hue="method")
# Out:
# <AxesSubplot:xlabel='labeled_pool_size', ylabel='eval_sparse_categorical_accuracy'>

# %%
df_mc_methods = Frame.split_by(df_mc, "method")
