# %%
import os, sys, importlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
BASE_PATH = os.path.join(os.getcwd(), "..", "..")
MODULES_PATH = os.path.join(BASE_PATH, "modules")
DATASET_PATH = os.path.join(BASE_PATH, "datasets", "regression", "insurance_forecast.csv")

# %%
sys.path.append(MODULES_PATH)

# %% [markdown]
# # Inspect data

# %%
data = pd.read_csv(DATASET_PATH)

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Check data
# Charges needed to be normalized
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Missing data?
data.isna().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1, 1, figsize=(10, 5))
ax = sns.histplot(data["charges"], kde=True, color="c")
plt.title("Distribution of charges")
# Out:
# Text(0.5, 1.0, 'Distribution of charges')

# %%
# Use log transformation to make distribution closer to normal distribution
f, ax = plt.subplots(1, 1, figsize=(10, 5))
ax = sns.histplot(np.log10(data["charges"]), kde=True, color='r')

# %%
# Highest charges in southeas
charges = data["charges"].groupby(data.region).sum().sort_values(ascending=True)
f, ax = plt.subplots(1, 1, figsize=(8, 6))
ax = sns.barplot(x=charges.head(), y=charges.head().index, palette="Blues")

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 5))
ax = sns.barplot(x="region", y="charges", hue="sex", data=data, palette="cool")

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 5))
ax = sns.barplot(x="region", y="charges", data=data, hue="smoker", palette="Reds_r")

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 5))
ax = sns.barplot(x="region", y="charges", hue="children", data=data, palette="Set1")

# %%
sns.lmplot(x="children", y="charges", data=data, hue="bmi", palette="Set1")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-245-d3e657f406ce> in <module>
# ----> 1 sns.lmplot(x="children", y="charges", data=data, hue="bmi", palette="Set1")
#
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/conda/lib/python3.8/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     626         scatter_kws=scatter_kws, line_kws=line_kws,
#     627     )
# --> 628     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     629
#     630     # TODO this will need to change when we relax string requirement
#
# /opt/conda/lib/python3.8/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     748
#     749             # Draw the plot
# --> 750             self._facet_plot(func, ax, args, kwargs)
#     751
#     752         # Finalize the annotations and layout
#
# /opt/conda/lib/python3.8/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     773             plot_args = []
#     774             plot_kwargs["ax"] = ax
# --> 775         func(*plot_args, **plot_kwargs)
#     776
#     777         # Sort out the supporting information
#
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/conda/lib/python3.8/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     836     scatter_kws["marker"] = marker
#     837     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 838     plotter.plot(ax, scatter_kws, line_kws)
#     839     return ax
#     840
#
# /opt/conda/lib/python3.8/site-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     368
#     369         if self.fit_reg:
# --> 370             self.lineplot(ax, line_kws)
#     371
#     372         # Label the axes
#
# /opt/conda/lib/python3.8/site-packages/seaborn/regression.py in lineplot(self, ax, kws)
#     411         """Draw the model."""
#     412         # Fit the regression model
# --> 413         grid, yhat, err_bands = self.fit_regression(ax)
#     414         edges = grid[0], grid[-1]
#     415
#
# /opt/conda/lib/python3.8/site-packages/seaborn/regression.py in fit_regression(self, ax, x_range, grid)
#     225             err_bands = None
#     226         else:
# --> 227             err_bands = utils.ci(yhat_boots, ci, axis=0)
#     228
#     229         return grid, yhat, err_bands
#
# /opt/conda/lib/python3.8/site-packages/seaborn/utils.py in ci(a, which, axis)
#     372     """Return a percentile range from an array of values."""
#     373     p = 50 - which / 2, 50 + which / 2
# --> 374     return np.nanpercentile(a, p, axis)
#     375
#     376
#
# <__array_function__ internals> in nanpercentile(*args, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/numpy/lib/nanfunctions.py in nanpercentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    1241     if not function_base._quantile_is_valid(q):
#    1242         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 1243     return _nanquantile_unchecked(
#    1244         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    1245
#
# /opt/conda/lib/python3.8/site-packages/numpy/lib/nanfunctions.py in _nanquantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    1366         return np.nanmean(a, axis, out=out, keepdims=keepdims)
#    1367
# -> 1368     r, k = function_base._ureduce(
#    1369         a, func=_nanquantile_ureduce_func, q=q, axis=axis, out=out,
#    1370         overwrite_input=overwrite_input, interpolation=interpolation
#
# /opt/conda/lib/python3.8/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3427         keepdim = (1,) * a.ndim
#    3428
# -> 3429     r = func(a, **kwargs)
#    3430     return r, keepdim
#    3431
#
# /opt/conda/lib/python3.8/site-packages/numpy/lib/nanfunctions.py in _nanquantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation)
#    1387         result = _nanquantile_1d(part, q, overwrite_input, interpolation)
#    1388     else:
# -> 1389         result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
#    1390                                      overwrite_input, interpolation)
#    1391         # apply_along_axis fills in collapsed axis with results.
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     399     # save the first result, then compute and save all remaining results
#     400     buff[ind0] = res
# --> 401     for ind in inds:
#     402         buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     403
#
# /opt/conda/lib/python3.8/site-packages/numpy/lib/shape_base.py in <genexpr>(.0)
#     368     # prevent 0d arrays decaying to scalars, which fixes gh-8642
#     369     inds = ndindex(inarr_view.shape[:-1])
# --> 370     inds = (ind + (Ellipsis,) for ind in inds)
#     371
#     372     # invoke the function on the first item
#
# /opt/conda/lib/python3.8/site-packages/numpy/lib/index_tricks.py in __next__(self)
#     664         """
#     665         next(self._it)
# --> 666         return self._it.multi_index
#     667
#     668
#
# KeyboardInterrupt:

# %% [markdown]
# ## Smoking as a charging factor
#
# - prone to pay more charges per age group
# -

# %%
print("Smokers: " + str(np.sum(data["smoker"] == "yes")))
print("Non-Smoker: " + str(np.sum(data["smoker"] == "no")))
# Out:
# Smokers: 274
# Non-Smoker: 1064

# %%
ax = sns.lmplot(x="age", y="charges", data=data, hue="smoker", palette="Set1")

# %%
# children not cause of higher charges
ax = sns.lmplot(x="children", y="charges", hue="smoker", data=data, palette="Set1")

# %%
# Smokers with high bmi are charged more than none smokers
ax = sns.lmplot(x="bmi", y="charges", hue="smoker", data=data, palette="Set1")

# %% [markdown]
# # Pre-process data
# - [Encode categorical](https://towardsdatascience.com/all-about-categorical-variable-encoding-305f3361fd02)
# - [Normalize Charges](https://www.codecademy.com/articles/normalization#:~:text=Min%2Dmax%20normalization%20is%20one,decimal%20between%200%20and%201.&text=That%20data%20is%20just%20as%20squished%20as%20before!)
#
#
# ### Nominal features
#
# - sex
# - region
# - children
#
# ### Ordinal
#
# - smoker

# %%
import pipeline.insurance as pip_ins
importlib.reload(pip_ins)
# Out:
# <module 'pipeline.insurance' from '/home/jovyan/work/dataset_exploration/../../modules/pipeline/insurance.py'>

# %%
preprocessed_data = pip_ins.preprocess(data)
preprocessed_data.head()
# Out:
#    age     bmi  children  smoker   charges
# 0   19  27.900         0       1  0.251611
# 1   18  33.770         1       0  0.009636
# 2   28  33.000         3       0  0.053115
# 3   33  22.705         0       0  0.333010
# 4   32  28.880         0       0  0.043816

# %%
preprocessed_data.describe()
# Out:
#                age          bmi     children       smoker      charges
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025    30.663397     0.193916     0.193916     0.193916
# std      14.049960     6.098187     0.021372     0.152176     0.193301
# min      18.000000    15.960000     0.122336     0.116721     0.000000
# 25%      27.000000    26.296250     0.179479     0.116721     0.057757
# 50%      39.000000    30.400000     0.185308     0.116721     0.131849
# 75%      51.000000    34.693750     0.222698     0.116721     0.247700
# max      64.000000    53.130000     0.227195     0.493680     1.000000

# %% [markdown]
# # Check corelations

# %%
preprocessed_data.corr()
# Out:
#                age       bmi  children    smoker   charges
# age       1.000000  0.109272  0.060272 -0.025019  0.299008
# bmi       0.109272  1.000000  0.027919  0.003750  0.198341
# children  0.060272  0.027919  1.000000  0.056504  0.110565
# smoker   -0.025019  0.003750  0.056504  1.000000  0.787251
# charges   0.299008  0.198341  0.110565  0.787251  1.000000

# %%
corr_heatmap = preprocessed_data.corr()

plt.pcolor(corr_heatmap)
plt.xticks(np.arange(0.5, len(corr_heatmap.columns), 1), corr_heatmap.columns)
plt.yticks(np.arange(0.5, len(corr_heatmap.index), 1), corr_heatmap.index)
plt.show()

# %%
plt.scatter(preprocessed_data["charges"], preprocessed_data["smoker"])

# %% [markdown]
# ## Check distribution of data

# %%
preprocessed_data.columns
# Out:
# Index(['age', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1, 1, figsize=(10, 5))
ax = sns.histplot(data["bmi"], kde = True, color = "c")
plt.title("Distribution of bmi")
# Out:
# Text(0.5, 1.0, 'Distribution of bmi')

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1, 1, figsize=(10, 5))
ax = sns.histplot(data["children"], kde = True, color = "c")

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1, 1, figsize=(10, 5))
ax = sns.histplot(data["age"], kde = True, color = "c")
plt.title("Distribution of age")
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %% [markdown]
# ## Train linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
(X_train, X_test, y_train, y_test) = train_test_split(clean_data.iloc[:, :-1], clean_data["charges"], train_size=.90)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1204, 4)
# (134, 4)

# %%
lin_model = LinearRegression()
lin_model.fit(X_train, y_train)
lin_model.score(X_test, y_test)
# Out:
# 0.8155667726091423

# %%
X_test.iloc[0]
# Out:
# age         44.000000
# bmi         38.060000
# children     0.179479
# smoker       0.493680
# Name: 488, dtype: float64

# %%
lin_model.predict(X_test.iloc[:1])
# Out:
# array([0.54249324])

# %%
y_test.iloc[0]
# Out:
# 0.7624000647506722
