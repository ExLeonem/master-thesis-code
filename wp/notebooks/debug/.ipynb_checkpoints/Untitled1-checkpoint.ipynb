# %%
# %load_ext autoreload
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
BASE_PATH = os.path.join(os.getcwd(), "..", "..")
MODULES_PATH = os.path.join(BASE_PATH, "modules")
METRICS_PATH = os.path.join(BASE_PATH, "metrics")
STAT_PATH = os.path.join(BASE_PATH, "stats", "local")

# %%
sys.path.append(MODULES_PATH)
sys.path.append(os.path.join(BASE_PATH, "tf_al"))

# %%
# %autoreload 2
from tf_al import ExperimentSuitMetrics
from utils import MetricsTransformer, Frame, ExperimentFrame, FrameScores, Stats

# %%
dtypes = {
    "run": int,
    "iteration": int,
    "train_time": float,
    "eval_sparse_categorical_crossentropy": float,
    "eval_sparse_categorical_accuracy": float,
    "query_time": float,
    "labeled_pool_size": int,
    "unlabeled_pool_size": int,
    "method": str
}

# %%
base_experiment_path = os.path.join(METRICS_PATH, "mnist_reprod_test")
metrics_handler = ExperimentSuitMetrics(base_experiment_path)
df_mc = MetricsTransformer.load_from_dir(metrics_handler, "mc_dropout", dtype=dtypes)
scores = FrameScores(accuracy_column="eval_sparse_categorical_accuracy")
mc_frame = ExperimentFrame(df_mc, scores=scores)

# %%
df_mc = mc_frame.get_frame()

# %%
selector = np.logical_and(df_mc["iteration"] == 1, df_mc["run"] == 1)
df_mc[selector]
# Out:
#    auc  eval_sparse_categorical_accuracy  \
# 0  NaN                              0.63
# 0  NaN                              0.63
# 0  NaN                              0.63
# 0  NaN                              0.63
# 0  0.0                              0.63
# 0  0.0                              0.68
#
#    eval_sparse_categorical_crossentropy            eval_time indices_selected  \
# 0                              1.616623  0.06999707221984863          [59849]
# 0                              1.617485  0.07544493675231934          [32768]
# 0                              1.616632  0.06921100616455078          [44580]
# 0                              1.617485  0.07589149475097656           [7533]
# 0                              1.519699   3.5676984786987305          [57351]
# 0                              1.198982  0.07376956939697266           [7265]
#
#    iteration  labeled_pool_size  mean_leff  mean_qeff           method  \
# 0          1                 20        NaN   0.000000             BALD
# 0          1                 20        NaN   0.195145     Max. Entropy
# 0          1                 20        NaN   0.205898  Max. Var. Ratio
# 0          1                 20        NaN   0.200775        Mean Std.
# 0          1                 20        1.0   1.000000           Random
# 0          1                 20        1.0   1.000000           Random
#
#         model    query_time  run  std_leff  std_qeff  \
# 0  MC Dropout  3.560812e+01    0       NaN       0.0
# 0  MC Dropout  2.865936e+01    0       NaN       0.0
# 0  MC Dropout  2.827649e+01    0       NaN       0.0
# 0  MC Dropout  2.845888e+01    0       NaN       0.0
# 0  MC Dropout  9.955864e-07    0       0.0       1.0
# 0  MC Dropout  1.001606e-06    1       0.0       1.0
#
#                                           train_loss  \
# 0  [2.638448476791382, 2.27034592628479, 2.054384...
# 0  [2.638448476791382, 2.27034592628479, 2.054384...
# 0  [2.638448476791382, 2.27034592628479, 2.054384...
# 0  [2.638448476791382, 2.27034592628479, 2.054384...
# 0  [2.638448476791382, 2.27034592628479, 2.054384...
# 0  [2.3603515625, 2.464395046234131, 1.7120403051...
#
#                    train_sparse_categorical_accuracy  train_time  \
# 0  [0.5, 0.20000000298023224, 0.20000000298023224...    1.452309
# 0  [0.5, 0.20000000298023224, 0.20000000298023224...    1.412076
# 0  [0.5, 0.20000000298023224, 0.20000000298023224...    1.422909
# 0  [0.5, 0.20000000298023224, 0.20000000298023224...    1.434736
# 0  [0.0, 0.20000000298023224, 0.20000000298023224...    9.882041
# 0  [0.5, 0.05000000074505806, 0.44999998807907104...    1.573490
#
#    unlabeled_pool_size
# 0                59879
# 0                59879
# 0                59879
# 0                59879
# 0                59879
# 0                59879
