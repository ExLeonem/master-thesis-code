# %%
# %load_ext autoreload
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
BASE_PATH = os.path.join(os.getcwd(), "..", "..")
MODULES_PATH = os.path.join(BASE_PATH, "modules")
METRICS_PATH = os.path.join(BASE_PATH, "metrics")
STAT_PATH = os.path.join(BASE_PATH, "stats", "local")

# %%
sys.path.append(MODULES_PATH)
sys.path.append(os.path.join(BASE_PATH, "tf_al"))

# %%
# %autoreload 2
from tf_al import ExperimentSuitMetrics
from utils import MetricsTransformer, Frame, ExperimentFrame, FrameScores, Stats

# %%
dtypes = {
    "run": int,
    "iteration": int,
    "train_time": float,
    "eval_sparse_categorical_crossentropy": float,
    "eval_sparse_categorical_accuracy": float,
    "query_time": float,
    "labeled_pool_size": int,
    "unlabeled_pool_size": int,
    "method": str
}

# %%
base_experiment_path = os.path.join(METRICS_PATH, "mnist_reprod_test")
metrics_handler = ExperimentSuitMetrics(base_experiment_path)
df_mc = MetricsTransformer.load_from_dir(metrics_handler, "mc_dropout", dtype=dtypes)
scores = FrameScores(accuracy_column="eval_sparse_categorical_accuracy")
mc_frame = ExperimentFrame(df_mc, scores=scores)

# %%
df_mc = mc_frame.get_frame()

# %%
selector = np.logical_and(df_mc["iteration"] == 1, df_mc["run"] == 0)
df_mc[selector]
# Out:
#    run       model           method  \
# 0    0  MC Dropout             BALD
# 0    0  MC Dropout     Max. Entropy
# 0    0  MC Dropout  Max. Var. Ratio
# 0    0  MC Dropout        Mean Std.
# 0    0  MC Dropout           Random
#
#                                           train_loss  \
# 0  [2.5188941955566406, 2.5068163871765137, 1.921...
# 0  [2.5188941955566406, 2.5068163871765137, 1.921...
# 0  [2.5188941955566406, 2.5068163871765137, 1.921...
# 0  [2.5188941955566406, 2.5068163871765137, 1.921...
# 0  [2.5188941955566406, 2.5068163871765137, 1.921...
#
#                    train_sparse_categorical_accuracy  train_time  std_qeff  \
# 0  [0.5249999761581421, 0.05000000074505806, 0.40...    1.241684       NaN
# 0  [0.5249999761581421, 0.05000000074505806, 0.40...    1.349753       NaN
# 0  [0.5249999761581421, 0.05000000074505806, 0.40...    1.302023       NaN
# 0  [0.5249999761581421, 0.05000000074505806, 0.40...    1.471393       NaN
# 0  [0.05000000074505806, 0.05000000074505806, 0.4...    9.997386       NaN
#
#    mean_qeff  query_time  eval_sparse_categorical_crossentropy  \
# 0   0.000000   36.448545                              2.383517
# 0   0.215691   28.597867                              2.365324
# 0   0.215110   28.619042                              2.383139
# 0   0.213266   28.686142                              2.365325
# 0   1.000000    0.050817                              2.245856
#
#    eval_sparse_categorical_accuracy            eval_time  \
# 0                              0.45  0.07909846305847168
# 0                              0.45  0.06927132606506348
# 0                              0.45  0.07070398330688477
# 0                              0.45  0.07306838035583496
# 0                              0.42   3.5009591579437256
#
#                                     indices_selected  iteration  \
# 0  [5153, 28193, 45714, 5339, 46212, 57798, 1251,...          1
# 0  [43878, 11014, 45714, 42930, 12063, 31987, 657...          1
# 0  [42930, 54021, 21056, 55575, 30463, 47885, 352...          1
# 0  [49958, 8606, 1251, 25050, 45714, 56778, 12063...          1
# 0  [30873, 5101, 58247, 28301, 23877, 14306, 2376...          1
#
#    labeled_pool_size  unlabeled_pool_size
# 0                 20                59870
# 0                 20                59870
# 0                 20                59870
# 0                 20                59870
# 0                 20                59870
